# %%
rq1 = df[['price', 'average_playtime_forever', 'pct_pos_total']].dropna()

# Correlation table
rq1_corr = rq1.corr()
rq1_corr.to_csv('rq1_correlation.csv')

# Scatter plot
plt.figure()
plt.scatter(rq1['price'], rq1['average_playtime_forever'])
plt.xlabel('Price')
plt.ylabel('Playtime')
plt.title('Price vs Engagement')
plt.savefig('rq1_figure.pdf')
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 rq1 = df[['price', 'average_playtime_forever', 'pct_pos_total']].dropna()
#       3 # Correlation table
#       4 rq1_corr = rq1.corr()
#
# NameError: name 'df' is not defined
