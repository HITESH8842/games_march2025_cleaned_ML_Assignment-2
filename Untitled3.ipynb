# %%
# !zip -r assignment2.zip "assignment 2"
# Out:
# 'zip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os

os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Figures',
#  'games_march2025_cleaned.csv',
#  'Models',
#  'Model_Accuracy_Comparison.csv',
#  'Model_Accuracy_Comparison.pdf',
#  'Model_Performance_Comparison.csv',
#  'requirement.ipynb',
#  'RQ1.ipynb',
#  'rq1_correlation.csv',
#  'RQ1_Correlation_Table.csv',
#  'RQ1_Correlation_Table.png',
#  'RQ1_Group_Table.csv',
#  'RQ1_Group_Table.png',
#  'RQ1_Playtime_by_PriceGroup.pdf',
#  'RQ1_Playtime_by_PriceGroup.PNG',
#  'RQ1_Price_vs_Playtime.pdf',
#  'RQ1_Price_vs_Playtime.PNG',
#  'RQ1_Price_vs_Satisfaction.pdf',
#  'RQ1_Price_vs_Satisfaction.PNG',
#  'RQ1_Satisfaction_by_PriceGroup.pdf',
#  'RQ1_Satisfaction_by_PriceGroup.PNG',
#  'RQ2.ipynb',
#  'RQ2_Activity_by_Discount.png',
#  'RQ2_Correlation_Table.png',
#  'RQ2_Discount_vs_PeakCCU.png',
#  'RQ2_Discount_vs_Reviews.png',
#  'RQ2_Group_Table.png',
#  'RQ2_Popularity_by_Discount.png',
#  'RQ3.ipynb',
#  'RQ3_Fig1_Critic_vs_User.png',
#  'RQ3_Fig2_Critic_vs_Satisfaction.png',
# ...
